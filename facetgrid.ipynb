# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col="day", row="sex")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(sns.distplot, "tip")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(sns.distplot, "total_bill", color='r')

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(sns.scatterplot, "total_bill", "tip", size="size")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-39ec971eadb7> in <module>
#       1 g = sns.FacetGrid(tips, col="time",  row="smoker")
# ----> 2 g = g.map(sns.scatterplot, "total_bill", "tip", size="size")
#
# ~/Desktop/pandas-tutorial/env/lib/python3.7/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     752
#     753             # Draw the plot
# --> 754             self._facet_plot(func, ax, plot_args, kwargs)
#     755
#     756         # Finalize the annotations and layout
#
# ~/Desktop/pandas-tutorial/env/lib/python3.7/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ~/Desktop/pandas-tutorial/env/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# ~/Desktop/pandas-tutorial/env/lib/python3.7/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     850
#     851         plot_data = self.establish_variables(
# --> 852             x, y, hue, size, style, units, data
#     853         )
#     854
#
# ~/Desktop/pandas-tutorial/env/lib/python3.7/site-packages/seaborn/relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#     140                 if isinstance(var, string_types):
#     141                     err = "Could not interpret input '{}'".format(var)
# --> 142                     raise ValueError(err)
#     143
#     144             # Extract variable names
#
# ValueError: Could not interpret input 'size'

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", size="size")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map_dataframe(sns.scatterplot, "total_bill", "tip", size="size")

# %%
g = sns.FacetGrid(tips, col="smoker", col_order=["Yes", "No"])
g = g.map(sns.distplot, "total_bill", color="m")

# %%
g = sns.FacetGrid(tips, col="smoker", row="sex")
g = (g.map(sns.scatterplot, "total_bill", "tip", color="g")
       .set_axis_labels("Total bill (US Dollars)", "Tip"))

# %%
g = sns.FacetGrid(tips, col="size", col_wrap=3)
g = (g.map(sns.distplot, "tip", color="c", kde=False)
       .set_titles("{col_name} diners"))
