# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
g = sns.residplot(x="total_bill", y="tip", data=tips)

# %%
g = sns.residplot(x="total_bill", y="tip", data=tips, lowess=True)

# %%
anscombe = sns.load_dataset("anscombe")

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"));

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'II'"), order=2);

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'III'"));

# %%
sns.residplot(x="x", y="y", data=anscombe.query("dataset == 'III'"), robust=True);

# %%
sns.coefplot("tip ~ total_bill + C(day)", tips, intercept=True, ci=90)

# %%
sns.coefplot("tip ~ total_bill + C(day)", tips, intercept=True, ci=90, groupby='smoker')

# %%
# Generate a random dataset with strong simple effects and an interaction
n = 80
rs = np.random.RandomState(11)
x1 = rs.randn(n)
x2 = x1 / 5 + rs.randn(n)
b0, b1, b2, b3 = .5, .25, -1, 2
y = b0  + b1 * x1 + b2 * x2 + b3 * x1 * x2 + rs.randn(n)
df = pd.DataFrame(np.c_[x1, x2, y], columns=["x1", "x2", "y"])

# Show a scatterplot of the predictors with the estimated model surface
sns.interactplot("x1", "x2", "y", df, logistic=False)
